# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
def bezier_curve(start, end, cost, ax):
    direction=1
    if start>end:
        direction=-1
    p0 = np.array([start, 0])
    p1 = np.array([(start + end) / 2, (direction)*cost]) # height of the control point
    p2 = np.array([end, 0])

    t = np.linspace(0, 1, num=100)[:, None]
    curve = (1 - t)**2 * p0 + 2 * (1 - t) * t * p1 + t**2 * p2
    ax.plot(curve[:, 0], curve[:, 1], '-')
def plot(data):
    fig, ax = plt.subplots(figsize=(12, 8))
    for index, row in data.iterrows():
        bezier_curve(row['start'], row['end'], row['cost'], ax)
    ax.set_xlabel('Node position')
    ax.set_ylabel('cost')
    ax.set_title('shortest path')

    plt.show()

# %%
path="path/2.200000_0.800000_30000"
temp_data=np.loadtxt(path)
print(temp_data[0])
data_list=[]
data_frame=[]
single=[]
n=int(path.split("_")[2])
print(n)
start=n*0.2
end=n*0.8
for i in temp_data:
    i[0]=(i[0]-6400)/(23600-6400)
    i[1]=(i[1]-6400)/(23600-6400)
    single.append(i)
    if i[1]==1:
        data_list.append(single)
        data_frame.append(pd.DataFrame(single,columns=["start","end","cost"]))
        single=[]

data_frame
# Out:
# [6.40000e+03 6.40100e+03 5.13689e-03]
# 30000
# [       start       end      cost
#  0   0.000000  0.000058  0.005137
#  1   0.000058 -0.000640  0.013965
#  2  -0.000640 -0.000233  0.009016
#  3  -0.000233  0.005581  0.001035
#  4   0.005581  0.171919  0.000360
#  5   0.171919  0.142151  0.000001
#  6   0.142151  0.542791  0.000365
#  7   0.542791  0.520116  0.000022
#  8   0.520116  0.499186  0.000003
#  9   0.499186  0.466860  0.000216
#  10  0.466860  0.708430  0.000702
#  11  0.708430  1.021628  0.000530
#  12  1.021628  1.011221  0.000063
#  13  1.011221  1.004360  0.000673
#  14  1.004360  1.001628  0.000129
#  15  1.001628  1.001337  0.000075
#  16  1.001337  1.000174  0.000285
#  17  1.000174  0.999709  0.003056
#  18  0.999709  0.999826  0.000039
#  19  0.999826  0.999942  0.000534
#  20  0.999942  1.000000  0.002498,
#        start       end          cost
#  0  0.000000 -0.010291  1.219130e-07
#  1 -0.010291 -0.111395  2.807370e-04
#  2 -0.111395  0.926279  4.744760e-04
#  3  0.926279  1.000000  3.035100e-02,
#        start       end      cost
#  0  0.000000  0.002326  0.058075
#  1  0.002326 -0.023081  0.000106
#  2 -0.023081  0.251453  0.000072
#  3  0.251453  0.973314  0.000170
#  4  0.973314  0.983895  0.000081
#  5  0.983895  0.992791  0.000102
#  6  0.992791  1.000058  0.053411
#  7  1.000058  1.000000  0.012032,
#        start       end      cost
#  0  0.000000 -0.000174  0.030999
#  1 -0.000174 -0.003663  0.001719
#  2 -0.003663  0.156686  0.000104
#  3  0.156686  1.090058  0.000071
#  4  1.090058  0.999593  0.008179
#  5  0.999593  0.999535  0.000260
#  6  0.999535  1.000000  0.018361,
#        start       end      cost
#  0  0.000000 -0.001977  0.093879
#  1 -0.001977 -0.003779  0.000860
#  2 -0.003779  0.013779  0.000659
#  3  0.013779  0.012791  0.000026
#  4  0.012791  0.021628  0.001658
#  5  0.021628  0.958837  0.001108
#  6  0.958837  1.000000  0.011544]

# %%
for i in data_frame:
    plot(i)

# %%
# Out:
#      start     end  weight_start  weight_end
# 0   2000.0  2001.0       1.11060     3.43341
# 1   2001.0  2003.0       3.43341     8.26392
# 2   2003.0  2008.0       8.26392     6.30404
# 3   2008.0  1983.0       6.30404     2.49144
# 4   1983.0  1982.0       2.49144   333.58800
# 5   1982.0  1963.0     333.58800     2.16002
# 6   1963.0  2462.0       2.16002     3.63295
# 7   2462.0  6473.0       3.63295    90.06720
# 8   6473.0  6420.0      90.06720     1.14983
# 9   6420.0  7447.0       1.14983     1.52667
# 10  7447.0  7871.0       1.52667     4.64676
# 11  7871.0  7955.0       4.64676     2.41573
# 12  7955.0  8093.0       2.41573     2.23663
# 13  8093.0  8090.0       2.23663     1.26492
# 14  8090.0  8089.0       1.26492     2.07865
# 15  8089.0  8063.0       2.07865     2.53454
# 16  8063.0  8011.0       2.53454     1.22275
# 17  8011.0  8006.0       1.22275     3.09237
# 18  8006.0  8003.0       3.09237     1.01202
# 19  8003.0  8000.0       1.01202     1.77692
