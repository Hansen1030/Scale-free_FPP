# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
def bezier_curve(start, end, cost, ax):
    direction=1
    if start>end:
        direction=-1
    p0 = np.array([start, 0])
    p1 = np.array([(start + end) / 2, (direction)*cost]) # height of the control point
    p2 = np.array([end, 0])

    t = np.linspace(0, 1, num=100)[:, None]
    curve = (1 - t)**2 * p0 + 2 * (1 - t) * t * p1 + t**2 * p2
    ax.plot(curve[:, 0], curve[:, 1], '-')
def plot(data):
    fig, ax = plt.subplots(figsize=(12, 8))
    for index, row in data.iterrows():
        bezier_curve(row['start'], row['end'], row['cost'], ax)
    ax.set_xlabel('Node position')
    ax.set_ylabel('cost')
    ax.set_title('shortest path')

    plt.show()

# %%
path="path/3.000000_0.800000_10000"
temp_data=np.loadtxt(path)
print(temp_data[0])
data_list=[]
data_frame=[]
single=[]
n=int(path.split("_")[2])
start=n*0.2
end=n*0.8
for i in temp_data:
    i[0]=(i[0]-start)/(end-start)
    i[1]=(i[1]-start)/(end-start)
    single.append(i)
    if i[1]==1:
        data_list.append(single)
        data_frame.append(pd.DataFrame(single,columns=["start","end","cost"]))
        single=[]

data_frame[0]
# Out:
# [2.00000e+03 1.94300e+03 5.56711e-02]
#        start       end          cost
# 0   0.000000 -0.009500  5.567110e-02
# 1  -0.009500 -0.095500  1.060290e-02
# 2  -0.095500  0.780833  9.028220e+00
# 3   0.780833  0.781333  9.850210e-09
# 4   0.781333  0.869000  5.904760e-02
# 5   0.869000  0.875333  5.484400e-02
# 6   0.875333  0.991000  9.950920e-02
# 7   0.991000  0.990833  2.898440e-02
# 8   0.990833  0.991333  5.138150e-02
# 9   0.991333  0.990167  2.034730e-03
# 10  0.990167  0.995000  2.364300e-03
# 11  0.995000  1.000500  3.820540e-02
# 12  1.000500  1.000000  6.244350e-02

# %%
for i in data_frame:
    plot(i)

# %%
# Out:
#      start     end  weight_start  weight_end
# 0   2000.0  2001.0       1.11060     3.43341
# 1   2001.0  2003.0       3.43341     8.26392
# 2   2003.0  2008.0       8.26392     6.30404
# 3   2008.0  1983.0       6.30404     2.49144
# 4   1983.0  1982.0       2.49144   333.58800
# 5   1982.0  1963.0     333.58800     2.16002
# 6   1963.0  2462.0       2.16002     3.63295
# 7   2462.0  6473.0       3.63295    90.06720
# 8   6473.0  6420.0      90.06720     1.14983
# 9   6420.0  7447.0       1.14983     1.52667
# 10  7447.0  7871.0       1.52667     4.64676
# 11  7871.0  7955.0       4.64676     2.41573
# 12  7955.0  8093.0       2.41573     2.23663
# 13  8093.0  8090.0       2.23663     1.26492
# 14  8090.0  8089.0       1.26492     2.07865
# 15  8089.0  8063.0       2.07865     2.53454
# 16  8063.0  8011.0       2.53454     1.22275
# 17  8011.0  8006.0       1.22275     3.09237
# 18  8006.0  8003.0       3.09237     1.01202
# 19  8003.0  8000.0       1.01202     1.77692
