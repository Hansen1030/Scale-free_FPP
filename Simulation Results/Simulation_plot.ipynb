# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('2.5 3 5000',header = None)
df.columns = ['Time']
df
# Out:
#          Time
# 0    108.0750
# 1    110.1950
# 2     66.9564
# 3     97.2973
# 4     58.1311
# ..        ...
# 995  109.9370
# 996   68.1296
# 997  131.6630
# 998  116.9600
# 999  119.0320
#
# [1000 rows x 1 columns]

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20, 12))
sns.histplot(data=df, x=df['Time'])
plt.title('Distribution of alpha = 3.5, gamma = 3, n = 5000')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20, 12))
sns.kdeplot(data=df, x=df['Time'])
plt.title('Distribution of alpha = 3.5, gamma = 3, n = 5000')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20, 12))
sns.boxplot(data=df, x=df['Time'])
plt.title('Distribution of alpha = 3.5, gamma = 3, n = 5000')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.show()

# %%
mean = np.mean(df,axis=0)
mean
# Out:
# Time    108.109367
# dtype: float64

# %%
variance = np.var(df,axis=0)
sd = np.sqrt(variance) 
print(variance)
print(sd)
# Out:
# Time    843.988534
# dtype: float64
# Time    29.051481
# dtype: float64

# %%
median = np.median(df)
median
# Out:
# 107.867
